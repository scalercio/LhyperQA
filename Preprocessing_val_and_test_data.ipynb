# %%
import pandas as pd
data = pd.read_csv('Elementary-NDMC-Test1.csv')
print(len(data))
data["question"][0]
# Out:
# 542
# 'What is the best conclusion that can be made upon discovering a fossil of a freshwater fish in a desert area? (A) The fish migrated from the ocean (B) The fish was unable to reproduce (C) A mountain used to be in this area (D) A river used to run through this area'

# %%
data["aux"]=data["question"].apply(lambda x: x.replace(" (A) ","scalercio").replace(" (B) ","scalercio").replace(" (C) ","scalercio").replace(" (D) ","scalercio").split("scalercio"))
data["aux"][541]
# Out:
# ['Which of these is the most important product of Virginia forests?',
#  'Pecan trees',
#  'Pine cones',
#  'Hardwood lumber',
#  'Maple leaves']

# %%
df=data.loc[data["AnswerKey"]!="E"]
df.index = range(len(df))
print(len(df))
df
# Out:
# 542
#            questionID originalQuestionID  totalPossiblePoint AnswerKey  \
# 0    ACTAAP_2008_5_10                 10                   1         D
# 1    ACTAAP_2008_5_12                 12                   1         A
# 2    ACTAAP_2008_5_13                 13                   1         A
# 3    ACTAAP_2008_5_14                 14                   1         A
# 4    ACTAAP_2008_5_15                 15                   1         A
# 5     ACTAAP_2008_5_5                  5                   1         D
# 6     ACTAAP_2009_5_1                  1                   1         A
# 7    ACTAAP_2009_5_12                 12                   1         B
# 8    ACTAAP_2009_5_15                 15                   1         D
# 9     ACTAAP_2009_5_4                  4                   1         D
# 10    ACTAAP_2009_5_8                  8                   1         B
# 11    ACTAAP_2010_5_1                  1                   1         A
# 12   ACTAAP_2010_5_12                 12                   1         C
# 13   ACTAAP_2010_5_13                 13                   1         A
# 14   ACTAAP_2010_5_15                 15                   1         D
# 15    ACTAAP_2010_5_2                  2                   1         D
# 16    ACTAAP_2010_5_5                  5                   1         C
# 17    ACTAAP_2010_5_7                  7                   1         B
# 18    ACTAAP_2010_5_8                  8                   1         A
# 19    ACTAAP_2010_5_9                  9                   1         A
# 20    ACTAAP_2011_5_1                  1                   1         B
# 21   ACTAAP_2011_5_13                 13                   1         A
# 22   ACTAAP_2011_5_14                 14                   1         D
# 23   ACTAAP_2011_5_16                 16                   1         B
# 24    ACTAAP_2011_5_6                  6                   1         C
# 25    ACTAAP_2011_5_8                  8                   1         C
# 26   ACTAAP_2013_5_13                 13                   1         D
# 27   ACTAAP_2013_5_17                 17                   1         A
# 28    ACTAAP_2013_5_4                  4                   1         B
# 29    ACTAAP_2013_5_5                  5                   1         B
# ..                ...                ...                 ...       ...
# 512   VASoL_2008_3_20                 20                   1         A
# 513   VASoL_2008_3_21                 21                   1         C
# 514   VASoL_2008_3_35                 35                   1         A
# 515   VASoL_2008_5_14                 14                   1         B
# 516   VASoL_2008_5_16                 16                   1         B
# 517   VASoL_2008_5_26                 26                   1         C
# 518   VASoL_2008_5_33                 33                   1         D
# 519   VASoL_2008_5_34                 34                   1         A
# 520   VASoL_2008_5_40                 40                   1         A
# 521   VASoL_2009_3_12                 12                   1         D
# 522    VASoL_2009_3_2                  2                   1         D
# 523   VASoL_2009_3_21                 21                   1         C
# 524   VASoL_2009_3_23                 23                   1         D
# 525   VASoL_2009_3_25                 25                   1         A
# 526    VASoL_2009_3_8                  8                   1         D
# 527   VASoL_2009_5_12                 12                   1         C
# 528   VASoL_2009_5_18                 18                   1         A
# 529   VASoL_2009_5_20                 20                   1         C
# 530   VASoL_2009_5_22                 22                   1         D
# 531   VASoL_2009_5_23                 23                   1         B
# 532   VASoL_2009_5_24                 24                   1         B
# 533    VASoL_2009_5_3                  3                   1         A
# 534   VASoL_2009_5_37                 37                   1         C
# 535    VASoL_2009_5_8                  8                   1         B
# 536   VASoL_2010_3_13                 13                   1         A
# 537   VASoL_2010_3_20                 20                   1         A
# 538    VASoL_2011_5_1                  1                   1         C
# 539   VASoL_2011_5_25                 25                   1         D
# 540   VASoL_2011_5_34                 34                   1         B
# 541   VASoL_2011_5_38                 38                   1         C
#
#      isMultipleChoiceQuestion  includesDiagram  \
# 0                           1                0
# 1                           1                0
# 2                           1                0
# 3                           1                0
# 4                           1                0
# 5                           1                0
# 6                           1                0
# 7                           1                0
# 8                           1                0
# 9                           1                0
# 10                          1                0
# 11                          1                0
# 12                          1                0
# 13                          1                0
# 14                          1                0
# 15                          1                0
# 16                          1                0
# 17                          1                0
# 18                          1                0
# 19                          1                0
# 20                          1                0
# 21                          1                0
# 22                          1                0
# 23                          1                0
# 24                          1                0
# 25                          1                0
# 26                          1                0
# 27                          1                0
# 28                          1                0
# 29                          1                0
# ..                        ...              ...
# 512                         1                0
# 513                         1                0
# 514                         1                0
# 515                         1                0
# 516                         1                0
# 517                         1                0
# 518                         1                0
# 519                         1                0
# 520                         1                0
# 521                         1                0
# 522                         1                0
# 523                         1                0
# 524                         1                0
# 525                         1                0
# 526                         1                0
# 527                         1                0
# 528                         1                0
# 529                         1                0
# 530                         1                0
# 531                         1                0
# 532                         1                0
# 533                         1                0
# 534                         1                0
# 535                         1                0
# 536                         1                0
# 537                         1                0
# 538                         1                0
# 539                         1                0
# 540                         1                0
# 541                         1                0
#
#                                      examName  schoolGrade  year  \
# 0                                      ACTAAP            5  2008
# 1                                      ACTAAP            5  2008
# 2                                      ACTAAP            5  2008
# 3                                      ACTAAP            5  2008
# 4                                      ACTAAP            5  2008
# 5                                      ACTAAP            5  2008
# 6                                      ACTAAP            5  2009
# 7                                      ACTAAP            5  2009
# 8                                      ACTAAP            5  2009
# 9                                      ACTAAP            5  2009
# 10                                     ACTAAP            5  2009
# 11                                     ACTAAP            5  2010
# 12                                     ACTAAP            5  2010
# 13                                     ACTAAP            5  2010
# 14                                     ACTAAP            5  2010
# 15                                     ACTAAP            5  2010
# 16                                     ACTAAP            5  2010
# 17                                     ACTAAP            5  2010
# 18                                     ACTAAP            5  2010
# 19                                     ACTAAP            5  2010
# 20                                     ACTAAP            5  2011
# 21                                     ACTAAP            5  2011
# 22                                     ACTAAP            5  2011
# 23                                     ACTAAP            5  2011
# 24                                     ACTAAP            5  2011
# 25                                     ACTAAP            5  2011
# 26                                     ACTAAP            5  2013
# 27                                     ACTAAP            5  2013
# 28                                     ACTAAP            5  2013
# 29                                     ACTAAP            5  2013
# ..                                        ...          ...   ...
# 512  Virginia Standards of Learning - Science            3  2008
# 513  Virginia Standards of Learning - Science            3  2008
# 514  Virginia Standards of Learning - Science            3  2008
# 515  Virginia Standards of Learning - Science            5  2008
# 516  Virginia Standards of Learning - Science            5  2008
# 517  Virginia Standards of Learning - Science            5  2008
# 518  Virginia Standards of Learning - Science            5  2008
# 519  Virginia Standards of Learning - Science            5  2008
# 520  Virginia Standards of Learning - Science            5  2008
# 521  Virginia Standards of Learning - Science            3  2009
# 522  Virginia Standards of Learning - Science            3  2009
# 523  Virginia Standards of Learning - Science            3  2009
# 524  Virginia Standards of Learning - Science            3  2009
# 525  Virginia Standards of Learning - Science            3  2009
# 526  Virginia Standards of Learning - Science            3  2009
# 527  Virginia Standards of Learning - Science            5  2009
# 528  Virginia Standards of Learning - Science            5  2009
# 529  Virginia Standards of Learning - Science            5  2009
# 530  Virginia Standards of Learning - Science            5  2009
# 531  Virginia Standards of Learning - Science            5  2009
# 532  Virginia Standards of Learning - Science            5  2009
# 533  Virginia Standards of Learning - Science            5  2009
# 534  Virginia Standards of Learning - Science            5  2009
# 535  Virginia Standards of Learning - Science            5  2009
# 536  Virginia Standards of Learning - Science            3  2010
# 537  Virginia Standards of Learning - Science            3  2010
# 538  Virginia Standards of Learning - Science            5  2011
# 539  Virginia Standards of Learning - Science            5  2011
# 540  Virginia Standards of Learning - Science            5  2011
# 541  Virginia Standards of Learning - Science            5  2011
#
#                                               question  subject category  \
# 0    What is the best conclusion that can be made u...  science     Test
# 1    In which case does a physical change occur? (A...  science     Test
# 2    Which is a characteristic of sedimentary rock?...  science     Test
# 3    Which is the order of the planets from closest...  science     Test
# 4    Which is true of a car that is accelerating al...  science     Test
# 5    Which action should be taken in order to ident...  science     Test
# 6    Which planet is fourth from the Sun in our sol...  science     Test
# 7    A student shines a flashlight on different col...  science     Test
# 8    Which is the best description of the brightnes...  science     Test
# 9    In the United States, windmills have been used...  science     Test
# 10   What cell part is found in plant cells but not...  science     Test
# 11   A layer of rock is found to contain a fossil o...  science     Test
# 12   Which scientist would be most likely to study ...  science     Test
# 13   Many things can contribute to the development ...  science     Test
# 14   Ana rolled her wagon down the ramp to reach th...  science     Test
# 15   In the 16005 Robert Hooke invented an improved...  science     Test
# 16   A group of fish was released into a local lake...  science     Test
# 17   Heat was applied to a substance. First the sub...  science     Test
# 18   Fossils of sea animals were found in a cave in...  science     Test
# 19   Which is an example of a hypothesis? (A) Large...  science     Test
# 20   For a science fair project, Jordan collects da...  science     Test
# 21   Which statement best describes the size of the...  science     Test
# 22   Which structure controls what enters both plan...  science     Test
# 23   Pat dissolves some table salt in water. She th...  science     Test
# 24   Which mineral, found in Arkansas, is an ore th...  science     Test
# 25   A scientist studies cellular respiration. He m...  science     Test
# 26   Which is the correct order of the planets from...  science     Test
# 27   Which is an example of a physical change? (A) ...  science     Test
# 28   An organism eats grass and is preyed upon by a...  science     Test
# 29   Sam looks into a fish pond and points at a gol...  science     Test
# ..                                                 ...      ...      ...
# 512  Which of these is an example of something bein...      NaN     Test
# 513  Which of these is MOST likely made from only o...      NaN     Test
# 514  A black bear eats many different things, inclu...      NaN     Test
# 515  Copper wire is often wrapped in plastic. Plast...      NaN     Test
# 516  Which of these best describes a tornado? (A) A...      NaN     Test
# 517  Which of these are the deepest parts of the oc...      NaN     Test
# 518  Michael Faraday showed how electric current in...      NaN     Test
# 519  Students notice that in the fall leaves of sug...      NaN     Test
# 520  A wild turkey's forest community includes (A) ...      NaN     Test
# 521  The BEST way to make a shadow on a living room...      NaN     Test
# 522  Which of these is MOST likely the hardest to b...      NaN     Test
# 523  From what source does almost all heat energy o...      NaN     Test
# 524  A metal rod is struck and starts to vibrate. W...      NaN     Test
# 525  Which job is done in Virginia only during the ...      NaN     Test
# 526  Which of these is needed in all stages of the ...      NaN     Test
# 527  What kind of energy do all moving objects have...      NaN     Test
# 528  A student makes a fruit drink by stirring a po...      NaN     Test
# 529  At which location are oceans the deepest? (A) ...      NaN     Test
# 530  Which of these describes rotation? (A) Mercury...      NaN     Test
# 531  When a tree is dormant, the tree is (A) dying ...      NaN     Test
# 532  Which type of storm causes the most flooding i...      NaN     Test
# 533  The Apollo 11 mission was able to retrieve sam...      NaN     Test
# 534  A group of students tested the effects of diff...      NaN     Test
# 535  Which of these best describes the Moon? (A) Ol...      NaN     Test
# 536  The teeth of a carnivore are MOSTLY - (A) poin...      NaN     Test
# 537  Having dry, hot weather for a long time can ca...      NaN     Test
# 538  Which of these is a natural resource of Virgin...      NaN     Test
# 539  All of the populations of species in an area m...      NaN     Test
# 540  Which layer of Earth is the thinnest? (A) Inne...      NaN     Test
# 541  Which of these is the most important product o...      NaN     Test
#
#                                                    aux
# 0    [What is the best conclusion that can be made ...
# 1    [In which case does a physical change occur?, ...
# 2    [Which is a characteristic of sedimentary rock...
# 3    [Which is the order of the planets from closes...
# 4    [Which is true of a car that is accelerating a...
# 5    [Which action should be taken in order to iden...
# 6    [Which planet is fourth from the Sun in our so...
# 7    [A student shines a flashlight on different co...
# 8    [Which is the best description of the brightne...
# 9    [In the United States, windmills have been use...
# 10   [What cell part is found in plant cells but no...
# 11   [A layer of rock is found to contain a fossil ...
# 12   [Which scientist would be most likely to study...
# 13   [Many things can contribute to the development...
# 14   [Ana rolled her wagon down the ramp to reach t...
# 15   [In the 16005 Robert Hooke invented an improve...
# 16   [A group of fish was released into a local lak...
# 17   [Heat was applied to a substance. First the su...
# 18   [Fossils of sea animals were found in a cave i...
# 19   [Which is an example of a hypothesis?, Large m...
# 20   [For a science fair project, Jordan collects d...
# 21   [Which statement best describes the size of th...
# 22   [Which structure controls what enters both pla...
# 23   [Pat dissolves some table salt in water. She t...
# 24   [Which mineral, found in Arkansas, is an ore t...
# 25   [A scientist studies cellular respiration. He ...
# 26   [Which is the correct order of the planets fro...
# 27   [Which is an example of a physical change?, br...
# 28   [An organism eats grass and is preyed upon by ...
# 29   [Sam looks into a fish pond and points at a go...
# ..                                                 ...
# 512  [Which of these is an example of something bei...
# 513  [Which of these is MOST likely made from only ...
# 514  [A black bear eats many different things, incl...
# 515  [Copper wire is often wrapped in plastic. Plas...
# 516  [Which of these best describes a tornado?, A w...
# 517  [Which of these are the deepest parts of the o...
# 518  [Michael Faraday showed how electric current i...
# 519  [Students notice that in the fall leaves of su...
# 520  [A wild turkey's forest community includes, in...
# 521  [The BEST way to make a shadow on a living roo...
# 522  [Which of these is MOST likely the hardest to ...
# 523  [From what source does almost all heat energy ...
# 524  [A metal rod is struck and starts to vibrate. ...
# 525  [Which job is done in Virginia only during the...
# 526  [Which of these is needed in all stages of the...
# 527  [What kind of energy do all moving objects hav...
# 528  [A student makes a fruit drink by stirring a p...
# 529  [At which location are oceans the deepest?, Mi...
# 530  [Which of these describes rotation?, Mercury g...
# 531  [When a tree is dormant, the tree is, dying, i...
# 532  [Which type of storm causes the most flooding ...
# 533  [The Apollo 11 mission was able to retrieve sa...
# 534  [A group of students tested the effects of dif...
# 535  [Which of these best describes the Moon?, Olde...
# 536  [The teeth of a carnivore are MOSTLY -, pointe...
# 537  [Having dry, hot weather for a long time can c...
# 538  [Which of these is a natural resource of Virgi...
# 539  [All of the populations of species in an area ...
# 540  [Which layer of Earth is the thinnest?, Inner ...
# 541  [Which of these is the most important product ...
#
# [542 rows x 13 columns]

# %%
df["q1"]=df["aux"].apply(lambda x: x[0])
df["a"]=df["aux"].apply(lambda x: x[1])
df["b"]=df["aux"].apply(lambda x: x[2])
df["c"]=df["aux"].apply(lambda x: x[3])

# %%
import numpy as np
df['d']=np.nan
for index, row in df.iterrows():
    #print(len(row['aux']))
    if(len(row['aux'])>=5):
        df['d'][index]=df["aux"][index][4]
    else:
        df['d'][index]="."
# Out:
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import re
# Preprocess the reviews
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"([.,!?])", r" \1 ", text)
    text = re.sub(r"[^a-zA-Z.,!?]+", r" ", text)
    return text
    
df.q1 = df.q1.apply(preprocess_text)
df.a = df.a.apply(preprocess_text)
df.b = df.b.apply(preprocess_text)
df.c = df.c.apply(preprocess_text)
df.d = df.d.apply(preprocess_text)

# %%
for index, row in df.iterrows():
    if(row["q1"].split(" ")[-1]==""):
        df["q1"][index]= row["q1"].split(" ")[:-1]
    else:
        df["q1"][index]= row["q1"].split(" ")
# Out:
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
for index, row in df.iterrows():
    if(row["a"].split(" ")[-1]==""):
        df["a"][index]= row["a"].split(" ")[:-1]
    else:
        df["a"][index]= row["a"].split(" ")
        
    if(row["b"].split(" ")[-1]==""):
        df["b"][index]= row["b"].split(" ")[:-1]
    else:
        df["b"][index]= row["b"].split(" ")
    
    if(row["c"].split(" ")[-1]==""):
        df["c"][index]= row["c"].split(" ")[:-1]
    else:
        df["c"][index]= row["c"].split(" ")
        
    if(row["d"].split(" ")[-1]==""):
        df["d"][index]= row["d"].split(" ")[:-1]
    else:
        df["d"][index]= row["d"].split(" ")
# Out:
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df["len_q1"]=df["q1"].apply(lambda x: len(x))
df["len_a"]=df["a"].apply(lambda x: len(x))
df["len_b"]=df["b"].apply(lambda x: len(x))
df["len_c"]=df["c"].apply(lambda x: len(x))
df["len_d"]=df["d"].apply(lambda x: len(x))

# %%
df["a1"]=np.nan
df["wa1"]=np.nan
df["wa2"]=np.nan
df["wa3"]=np.nan
for index, row in df.iterrows():
    if(row['AnswerKey']=="A"):
        df["a1"][index] = df["a"][index]
        df["wa1"][index] = df["b"][index]
        df["wa2"][index] = df["c"][index]
        df["wa3"][index] = df["d"][index]
    elif (row['AnswerKey']=="B"):
        df["a1"][index] = df["b"][index]
        df["wa1"][index] = df["a"][index]
        df["wa2"][index] = df["c"][index]
        df["wa3"][index] = df["d"][index]
    elif (row['AnswerKey']=="C"):
        df["a1"][index] = df["c"][index]
        df["wa1"][index] = df["b"][index]
        df["wa2"][index] = df["a"][index]
        df["wa3"][index] = df["d"][index]
    elif (row['AnswerKey']=="D"):
        df["a1"][index] = df["d"][index]
        df["wa1"][index] = df["b"][index]
        df["wa2"][index] = df["c"][index]
        df["wa3"][index] = df["a"][index]
# Out:
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/arthur/.virtualenvs/machine-learning/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df["len_a1"]=df["a1"].apply(lambda x: len(x))
df["len_wa1"]=df["wa1"].apply(lambda x: len(x))
df["len_wa2"]=df["wa2"].apply(lambda x: len(x))
df["len_wa3"]=df["wa3"].apply(lambda x: len(x))

# %%
df1=df[["AnswerKey","question","q1","a1","wa1", "wa2", "wa3", "len_a1", "len_wa1", "len_wa2", "len_wa3","len_q1","a","b", "c", "d","len_a", "len_b", "len_c", "len_d"]]
df1.to_csv('/home/arthur/learning/ml_and_dataScience/LhyperQA/test_data.csv',index=False)

# %%
new_data = pd.read_csv('/home/arthur/learning/ml_and_dataScience/LhyperQA/test_data.csv')
new_data
# Out:
#     AnswerKey                                           question  \
# 0           D  What is the best conclusion that can be made u...
# 1           A  In which case does a physical change occur? (A...
# 2           A  Which is a characteristic of sedimentary rock?...
# 3           A  Which is the order of the planets from closest...
# 4           A  Which is true of a car that is accelerating al...
# 5           D  Which action should be taken in order to ident...
# 6           A  Which planet is fourth from the Sun in our sol...
# 7           B  A student shines a flashlight on different col...
# 8           D  Which is the best description of the brightnes...
# 9           D  In the United States, windmills have been used...
# 10          B  What cell part is found in plant cells but not...
# 11          A  A layer of rock is found to contain a fossil o...
# 12          C  Which scientist would be most likely to study ...
# 13          A  Many things can contribute to the development ...
# 14          D  Ana rolled her wagon down the ramp to reach th...
# 15          D  In the 16005 Robert Hooke invented an improved...
# 16          C  A group of fish was released into a local lake...
# 17          B  Heat was applied to a substance. First the sub...
# 18          A  Fossils of sea animals were found in a cave in...
# 19          A  Which is an example of a hypothesis? (A) Large...
# 20          B  For a science fair project, Jordan collects da...
# 21          A  Which statement best describes the size of the...
# 22          D  Which structure controls what enters both plan...
# 23          B  Pat dissolves some table salt in water. She th...
# 24          C  Which mineral, found in Arkansas, is an ore th...
# 25          C  A scientist studies cellular respiration. He m...
# 26          D  Which is the correct order of the planets from...
# 27          A  Which is an example of a physical change? (A) ...
# 28          B  An organism eats grass and is preyed upon by a...
# 29          B  Sam looks into a fish pond and points at a gol...
# ..        ...                                                ...
# 512         A  Which of these is an example of something bein...
# 513         C  Which of these is MOST likely made from only o...
# 514         A  A black bear eats many different things, inclu...
# 515         B  Copper wire is often wrapped in plastic. Plast...
# 516         B  Which of these best describes a tornado? (A) A...
# 517         C  Which of these are the deepest parts of the oc...
# 518         D  Michael Faraday showed how electric current in...
# 519         A  Students notice that in the fall leaves of sug...
# 520         A  A wild turkey's forest community includes (A) ...
# 521         D  The BEST way to make a shadow on a living room...
# 522         D  Which of these is MOST likely the hardest to b...
# 523         C  From what source does almost all heat energy o...
# 524         D  A metal rod is struck and starts to vibrate. W...
# 525         A  Which job is done in Virginia only during the ...
# 526         D  Which of these is needed in all stages of the ...
# 527         C  What kind of energy do all moving objects have...
# 528         A  A student makes a fruit drink by stirring a po...
# 529         C  At which location are oceans the deepest? (A) ...
# 530         D  Which of these describes rotation? (A) Mercury...
# 531         B  When a tree is dormant, the tree is (A) dying ...
# 532         B  Which type of storm causes the most flooding i...
# 533         A  The Apollo 11 mission was able to retrieve sam...
# 534         C  A group of students tested the effects of diff...
# 535         B  Which of these best describes the Moon? (A) Ol...
# 536         A  The teeth of a carnivore are MOSTLY - (A) poin...
# 537         A  Having dry, hot weather for a long time can ca...
# 538         C  Which of these is a natural resource of Virgin...
# 539         D  All of the populations of species in an area m...
# 540         B  Which layer of Earth is the thinnest? (A) Inne...
# 541         C  Which of these is the most important product o...
#
#                                                     q1  \
# 0    ['what', 'is', 'the', 'best', 'conclusion', 't...
# 1    ['in', 'which', 'case', 'does', 'a', 'physical...
# 2    ['which', 'is', 'a', 'characteristic', 'of', '...
# 3    ['which', 'is', 'the', 'order', 'of', 'the', '...
# 4    ['which', 'is', 'true', 'of', 'a', 'car', 'tha...
# 5    ['which', 'action', 'should', 'be', 'taken', '...
# 6    ['which', 'planet', 'is', 'fourth', 'from', 't...
# 7    ['a', 'student', 'shines', 'a', 'flashlight', ...
# 8    ['which', 'is', 'the', 'best', 'description', ...
# 9    ['in', 'the', 'united', 'states', ',', 'windmi...
# 10   ['what', 'cell', 'part', 'is', 'found', 'in', ...
# 11   ['a', 'layer', 'of', 'rock', 'is', 'found', 't...
# 12   ['which', 'scientist', 'would', 'be', 'most', ...
# 13   ['many', 'things', 'can', 'contribute', 'to', ...
# 14   ['ana', 'rolled', 'her', 'wagon', 'down', 'the...
# 15   ['in', 'the', 'robert', 'hooke', 'invented', '...
# 16   ['a', 'group', 'of', 'fish', 'was', 'released'...
# 17   ['heat', 'was', 'applied', 'to', 'a', 'substan...
# 18   ['fossils', 'of', 'sea', 'animals', 'were', 'f...
# 19   ['which', 'is', 'an', 'example', 'of', 'a', 'h...
# 20   ['for', 'a', 'science', 'fair', 'project', ','...
# 21   ['which', 'statement', 'best', 'describes', 't...
# 22   ['which', 'structure', 'controls', 'what', 'en...
# 23   ['pat', 'dissolves', 'some', 'table', 'salt', ...
# 24   ['which', 'mineral', ',', 'found', 'in', 'arka...
# 25   ['a', 'scientist', 'studies', 'cellular', 'res...
# 26   ['which', 'is', 'the', 'correct', 'order', 'of...
# 27   ['which', 'is', 'an', 'example', 'of', 'a', 'p...
# 28   ['an', 'organism', 'eats', 'grass', 'and', 'is...
# 29   ['sam', 'looks', 'into', 'a', 'fish', 'pond', ...
# ..                                                 ...
# 512  ['which', 'of', 'these', 'is', 'an', 'example'...
# 513  ['which', 'of', 'these', 'is', 'most', 'likely...
# 514  ['a', 'black', 'bear', 'eats', 'many', 'differ...
# 515  ['copper', 'wire', 'is', 'often', 'wrapped', '...
# 516  ['which', 'of', 'these', 'best', 'describes', ...
# 517  ['which', 'of', 'these', 'are', 'the', 'deepes...
# 518  ['michael', 'faraday', 'showed', 'how', 'elect...
# 519  ['students', 'notice', 'that', 'in', 'the', 'f...
# 520  ['a', 'wild', 'turkey', 's', 'forest', 'commun...
# 521  ['the', 'best', 'way', 'to', 'make', 'a', 'sha...
# 522  ['which', 'of', 'these', 'is', 'most', 'likely...
# 523  ['from', 'what', 'source', 'does', 'almost', '...
# 524  ['a', 'metal', 'rod', 'is', 'struck', 'and', '...
# 525  ['which', 'job', 'is', 'done', 'in', 'virginia...
# 526  ['which', 'of', 'these', 'is', 'needed', 'in',...
# 527  ['what', 'kind', 'of', 'energy', 'do', 'all', ...
# 528  ['a', 'student', 'makes', 'a', 'fruit', 'drink...
# 529  ['at', 'which', 'location', 'are', 'oceans', '...
# 530  ['which', 'of', 'these', 'describes', 'rotatio...
# 531  ['when', 'a', 'tree', 'is', 'dormant', ',', 't...
# 532  ['which', 'type', 'of', 'storm', 'causes', 'th...
# 533  ['the', 'apollo', 'mission', 'was', 'able', 't...
# 534  ['a', 'group', 'of', 'students', 'tested', 'th...
# 535  ['which', 'of', 'these', 'best', 'describes', ...
# 536  ['the', 'teeth', 'of', 'a', 'carnivore', 'are'...
# 537  ['having', 'dry', ',', 'hot', 'weather', 'for'...
# 538  ['which', 'of', 'these', 'is', 'a', 'natural',...
# 539  ['all', 'of', 'the', 'populations', 'of', 'spe...
# 540  ['which', 'layer', 'of', 'earth', 'is', 'the',...
# 541  ['which', 'of', 'these', 'is', 'the', 'most', ...
#
#                                                     a1  \
# 0    ['a', 'river', 'used', 'to', 'run', 'through',...
# 1               ['ice', 'melts', 'into', 'water', '.']
# 2                            ['forms', 'in', 'layers']
# 3    ['mercury', ',', 'venus', ',', 'earth', ',', '...
# 4     ['its', 'kinetic', 'energy', 'is', 'increasing']
# 5    ['drag', 'an', 'edge', 'of', 'the', 'mineral',...
# 6                                             ['mars']
# 7                                            ['black']
# 8    ['it', 'is', 'of', 'average', 'brightness', 'c...
# 9                             ['wheel', 'and', 'axle']
# 10                                    ['cell', 'wall']
# 11   ['the', 'fish', 'and', 'dinosaur', 'both', 'li...
# 12                                       ['ecologist']
# 13                                    ['observations']
# 14   ['wheel', 'and', 'axle', ',', 'inclined', 'pla...
# 15   ['the', 'term', 'cell', 'to', 'describe', 'the...
# 16   ['sampling', 'fish', 'populations', 'in', 'the...
# 17                                           ['solid']
# 18            ['it', 'was', 'once', 'underwater', '.']
# 19   ['large', 'mice', 'will', 'eat', 'more', 'food...
# 20   ['the', 'name', 'of', 'the', 'insect', 'and', ...
# 21   ['the', 'sun', 'is', 'medium', 'sized', 'compa...
# 22                                ['cell', 'membrane']
# 23             ['the', 'growth', 'of', 'a', 'crystal']
# 24                                         ['bauxite']
# 25                                 ['jumping', 'rope']
# 26   ['mercury', ',', 'venus', ',', 'earth', ',', '...
# 27   ['breaking', 'an', 'object', 'into', 'smaller'...
# 28                    ['consumer', 'and', 'herbivore']
# 29                                      ['refraction']
# ..                                                 ...
# 512  ['taking', 'glass', 'bottles', 'to', 'a', 'pla...
# 513                             ['a', 'paper', 'clip']
# 514                                       ['omnivore']
# 515                                      ['insulator']
# 516  ['a', 'rotating', 'funnel', 'shaped', 'cloud',...
# 517                              ['ocean', 'trenches']
# 518                         ['a', 'magnetic', 'field']
# 519                              ['an', 'observation']
# 520                                        ['insects']
# 521  ['stand', 'between', 'a', 'light', 'and', 'the...
# 522                                ['wooden', 'board']
# 523                                     ['the', 'sun']
# 524  ['the', 'metal', 'rod', 'produces', 'sound', '.']
# 525                              ['picking', 'apples']
# 526                                            ['air']
# 527                              ['kinetic', 'energy']
# 528  ['the', 'powder', 'dissolves', 'in', 'the', 'w...
# 529                                ['ocean', 'trench']
# 530  ['earth', 'makes', 'one', 'turn', 'on', 'its',...
# 531                                       ['inactive']
# 532                                      ['hurricane']
# 533                      ['land', 'on', 'the', 'moon']
# 534  ['record', 'daily', 'information', 'in', 'a', ...
# 535                       ['smaller', 'than', 'earth']
# 536                                        ['pointed']
# 537                                        ['drought']
# 538                                     ['a', 'river']
# 539                                      ['community']
# 540                                          ['crust']
# 541                             ['hardwood', 'lumber']
#
#                                                    wa1  \
# 0    ['the', 'fish', 'was', 'unable', 'to', 'reprod...
# 1        ['bread', 'burns', 'in', 'a', 'toaster', '.']
# 2                           ['looks', 'very', 'shiny']
# 3    ['mars', ',', 'mercury', ',', 'earth', ',', 'v...
# 4    ['its', 'kinetic', 'energy', 'is', 'decreasing...
# 5              ['dip', 'the', 'mineral', 'in', 'acid']
# 6                                            ['earth']
# 7                                              ['red']
# 8    ['it', 'is', 'brighter', 'than', 'other', 'sta...
# 9                                           ['pulley']
# 10                                         ['nucleus']
# 11   ['the', 'fish', 'was', 'carried', 'far', 'inla...
# 12                                        ['engineer']
# 13                                   ['conversations']
# 14   ['pulley', ',', 'inclined', 'plane', ',', 'and...
# 15   ['detailed', 'observations', 'of', 'jupiter', ...
# 16   ['checking', 'the', 'lake', 'water', 'for', 'n...
# 17                                             ['gas']
# 18        ['it', 'was', 'once', 'much', 'warmer', '.']
# 19   ['one', 'flower', 'was', 'measured', 'to', 'be...
# 20   ['the', 'size', 'of', 'the', 'insect', 'and', ...
# 21   ['the', 'sun', 'is', 'the', 'largest', 'and', ...
# 22                                    ['cell', 'wall']
# 23                 ['purification', 'of', 'an', 'ore']
# 24                                          ['galena']
# 25                                       ['breathing']
# 26   ['mercury', ',', 'earth', ',', 'mars', ',', 'v...
# 27   ['allowing', 'an', 'iron', 'chain', 'to', 'rem...
# 28                     ['producer', 'and', 'consumer']
# 29                                      ['reflection']
# ..                                                 ...
# 512  ['using', 'the', 'same', 'foil', 'to', 'cover'...
# 513                                   ['a', 'bicycle']
# 514                                      ['carnivore']
# 515                                  ['electromagnet']
# 516  ['a', 'winter', 'storm', 'that', 'produces', '...
# 517                          ['continental', 'slopes']
# 518                                      ['chemicals']
# 519                                ['a', 'conclusion']
# 520                                       ['rainfall']
# 521  ['turn', 'off', 'the', 'lights', 'in', 'the', ...
# 522                                ['cloth', 'ribbon']
# 523                                          ['water']
# 524  ['the', 'metal', 'rod', 'becomes', 'heavier', ...
# 525                             ['feeding', 'animals']
# 526                                           ['eyes']
# 527                                ['solar', 'energy']
# 528          ['the', 'water', 'changes', 'color', '.']
# 529                               ['abyssal', 'plain']
# 530  ['the', 'moon', 'goes', 'around', 'earth', 'ev...
# 531                                          ['dying']
# 532                                        ['tornado']
# 533                           ['orbit', 'a', 'planet']
# 534  ['conduct', 'the', 'experiment', 'with', 'more...
# 535                         ['older', 'than', 'earth']
# 536                                        ['rounded']
# 537                                   ['thunderstorm']
# 538                                   ['a', 'glacier']
# 539                                          ['niche']
# 540                                  ['inner', 'core']
# 541                                  ['pine', 'cones']
#
#                                                    wa2  \
# 0    ['a', 'mountain', 'used', 'to', 'be', 'in', 't...
# 1      ['a', 'cake', 'bakes', 'in', 'an', 'oven', '.']
# 2                             ['contains', 'crystals']
# 3    ['earth', ',', 'venus', ',', 'mercury', ',', '...
# 4    ['its', 'potential', 'energy', 'is', 'increasi...
# 5    ['heat', 'the', 'mineral', 'until', 'it', 'mel...
# 6                                            ['venus']
# 7                                            ['white']
# 8    ['it', 'is', 'of', 'average', 'brightness', 'c...
# 9                                ['inclined', 'plane']
# 10                                       ['cytoplasm']
# 11   ['the', 'fish', 'and', 'dinosaur', 'were', 'fo...
# 12                                        ['botanist']
# 13             ['publications', 'and', 'calculations']
# 14   ['wedge', ',', 'wheel', 'and', 'axle', ',', 'a...
# 15   ['the', 'name', 'spectrum', 'for', 'the', 'col...
# 16   ['measuring', 'oxygen', 'levels', 'in', 'the',...
# 17                                          ['liquid']
# 18   ['it', 'has', 'become', 'a', 'rockier', 'place...
# 19   ['on', 'a', 'dark', 'night', ',', 'a', 'studen...
# 20   ['the', 'weight', 'of', 'the', 'insect', 'and'...
# 21   ['most', 'of', 'the', 'stars', 'in', 'the', 'u...
# 22                                     ['chloroplast']
# 23           ['a', 'liquid', 'becoming', 'a', 'solid']
# 24                                          ['quartz']
# 25                                        ['sleeping']
# 26   ['mercury', ',', 'venus', ',', 'mars', ',', 'e...
# 27   ['heating', 'a', 'brown', 'substance', 'until'...
# 28                   ['decomposer', 'and', 'producer']
# 29                                     ['diffraction']
# ..                                                 ...
# 512  ['wrapping', 'glasses', 'with', 'newspaper', '...
# 513                                    ['a', 'pencil']
# 514                                      ['herbivore']
# 515                                        ['circuit']
# 516  ['a', 'severe', 'weather', 'condition', 'with'...
# 517                         ['continental', 'shelves']
# 518                                 ['a', 'vibration']
# 519                                ['a', 'prediction']
# 520                                           ['soil']
# 521  ['sit', 'close', 'to', 'the', 'wall', 'near', ...
# 522                                ['leather', 'shoe']
# 523                                           ['wind']
# 524  ['the', 'metal', 'rod', 'attracts', 'other', '...
# 525                             ['selling', 'clothes']
# 526                                           ['soil']
# 527                                ['light', 'energy']
# 528   ['the', 'student', 'stirs', 'the', 'water', '.']
# 529                          ['mid', 'ocean', 'ridge']
# 530  ['earth', 'orbits', 'the', 'sun', 'about', 'ev...
# 531                              ['growing', 'taller']
# 532                                       ['blizzard']
# 533                          ['return', 'to', 'earth']
# 534  ['discuss', 'their', 'observations', 'with', '...
# 535  ['having', 'the', 'same', 'climate', 'as', 'ea...
# 536                                           ['wide']
# 537                                        ['tornado']
# 538                                       ['a', 'dam']
# 539                                         ['family']
# 540                                  ['outer', 'core']
# 541                                 ['pecan', 'trees']
#
#                                                    wa3  len_a1  len_wa1  \
# 0    ['the', 'fish', 'migrated', 'from', 'the', 'oc...       8        6
# 1    ['two', 'chemicals', 'form', 'a', 'new', 'subs...       5        6
# 2                           ['forms', 'from', 'magma']       3        3
# 3    ['venus', ',', 'earth', ',', 'mars', ',', 'mer...       7        7
# 4    ['its', 'potential', 'energy', 'is', 'decreasi...       5        6
# 5                          ['weigh', 'the', 'mineral']       9        5
# 6                                          ['jupiter']       1        1
# 7                                           ['yellow']       1        1
# 8    ['it', 'is', 'less', 'bright', 'than', 'planet...      10        7
# 9                                            ['lever']       3        1
# 10                                ['cell', 'membrane']       2        1
# 11   ['the', 'dinosaur', 'was', 'swimming', 'from',...      10       11
# 12                                    ['veterinarian']       1        1
# 13            ['calculations', 'and', 'conversations']       1        1
# 14       ['lever', ',', 'pulley', ',', 'and', 'wedge']       9        7
# 15   ['the', 'first', 'view', 'of', 'atoms', 'and',...      10        6
# 16   ['observing', 'the', 'surface', 'of', 'the', '...       9       10
# 17                                          ['plasma']       1        1
# 18   ['it', 'has', 'changed', 'little', 'from', 'th...       5        6
# 19   ['people', 'should', 'be', 'careful', 'to', 'p...      10        9
# 20   ['the', 'color', 'of', 'the', 'insect', 'and',...       9       10
# 21   ['most', 'of', 'the', 'stars', 'in', 'the', 'u...      10       12
# 22                                         ['nucleus']       2        2
# 23                 ['sedimentation', 'of', 'granules']       5        4
# 24                                         ['diamond']       1        1
# 25                               ['digesting', 'food']       2        1
# 26   ['mercury', ',', 'venus', ',', 'earth', ',', '...      15       15
# 27   ['reacting', 'vinegar', 'and', 'baking', 'soda...      10       12
# 28                  ['herbivore', 'and', 'decomposer']       3        3
# 29                                      ['absorption']       1        1
# ..                                                 ...     ...      ...
# 512  ['carrying', 'lunch', 'to', 'school', 'every',...      12        9
# 513                       ['a', 'pair', 'of', 'shoes']       3        2
# 514                                       ['producer']       1        1
# 515                                        ['current']       1        1
# 516  ['a', 'storm', 'that', 'forms', 'over', 'warm'...      10        7
# 517                              ['abyssal', 'plains']       2        2
# 518                                      ['molecules']       3        1
# 519                                ['an', 'inference']       2        2
# 520                                           ['wind']       1        1
# 521      ['hold', 'a', 'lamp', 'near', 'the', 'floor']       7        7
# 522                                 ['rubber', 'band']       2        2
# 523                                    ['the', 'moon']       2        1
# 524  ['the', 'metal', 'rod', 'becomes', 'a', 'liqui...       6        6
# 525                             ['building', 'houses']       2        2
# 526                                          ['wings']       1        1
# 527                            ['renewable', 'energy']       2        2
# 528  ['the', 'water', 'is', 'the', 'proper', 'tempe...       7        5
# 529                             ['volcanic', 'island']       2        2
# 530  ['mercury', 'goes', 'around', 'the', 'sun', 'e...      10        8
# 531                       ['growing', 'its', 'leaves']       1        1
# 532                               ['freezing', 'rain']       1        1
# 533                            ['walk', 'in', 'space']       4        3
# 534  ['make', 'up', 'explanations', 'for', 'the', '...       8       11
# 535  ['having', 'the', 'same', 'atmosphere', 'as', ...       3        3
# 536                                           ['flat']       1        1
# 537                                          ['flood']       1        1
# 538                            ['a', 'power', 'plant']       2        2
# 539                                         ['region']       1        1
# 540                                         ['mantle']       1        2
# 541                                ['maple', 'leaves']       2        2
#
#      len_wa2  len_wa3  len_q1  \
# 0          8        6      22
# 1          7        7       9
# 2          2        3       8
# 3          7        7      18
# 4          6        6      14
# 5          6        3      18
# 6          1        1      12
# 7          1        1      21
# 8          9        7      12
# 9          2        1      28
# 10         1        2      14
# 11        11       13      36
# 12         1        1      16
# 13         3        3      48
# 14         8        6      32
# 15         8        7      22
# 16         9       15      53
# 17         1        1      28
# 18         7        7      25
# 19        12        9       8
# 20        11       11      49
# 21        13       13      10
# 22         1        1      12
# 23         5        3      48
# 24         1        1      18
# 25         1        2      28
# 26        15       15      12
# 27        11       12       9
# 28         3        3      18
# 29         1        1      45
# ..       ...      ...     ...
# 512       11       11      11
# 513        2        4      12
# 514        1        1      37
# 515        1        1      13
# 516       10       13       8
# 517        2        2      11
# 518        2        1      10
# 519        2        2      28
# 520        1        1       7
# 521        8        6      14
# 522        2        2      11
# 523        1        2      12
# 524        7        7      17
# 525        2        2      12
# 526        1        1      15
# 527        2        2      10
# 528        6        7      23
# 529        3        2       8
# 530        8        8       6
# 531        2        3       9
# 532        1        2      16
# 533        3        3      22
# 534       10        7      41
# 535        6        6       8
# 536        1        1       7
# 537        1        1      12
# 538        2        3      10
# 539        1        1      12
# 540        2        1       8
# 541        2        2      12
#
#                                                      a  \
# 0    ['the', 'fish', 'migrated', 'from', 'the', 'oc...
# 1               ['ice', 'melts', 'into', 'water', '.']
# 2                            ['forms', 'in', 'layers']
# 3    ['mercury', ',', 'venus', ',', 'earth', ',', '...
# 4     ['its', 'kinetic', 'energy', 'is', 'increasing']
# 5                          ['weigh', 'the', 'mineral']
# 6                                             ['mars']
# 7                                              ['red']
# 8    ['it', 'is', 'less', 'bright', 'than', 'planet...
# 9                                            ['lever']
# 10                                         ['nucleus']
# 11   ['the', 'fish', 'and', 'dinosaur', 'both', 'li...
# 12                                        ['botanist']
# 13                                    ['observations']
# 14       ['lever', ',', 'pulley', ',', 'and', 'wedge']
# 15   ['the', 'first', 'view', 'of', 'atoms', 'and',...
# 16   ['measuring', 'oxygen', 'levels', 'in', 'the',...
# 17                                             ['gas']
# 18            ['it', 'was', 'once', 'underwater', '.']
# 19   ['large', 'mice', 'will', 'eat', 'more', 'food...
# 20   ['the', 'size', 'of', 'the', 'insect', 'and', ...
# 21   ['the', 'sun', 'is', 'medium', 'sized', 'compa...
# 22                                         ['nucleus']
# 23                 ['purification', 'of', 'an', 'ore']
# 24                                          ['quartz']
# 25                                        ['sleeping']
# 26   ['mercury', ',', 'venus', ',', 'earth', ',', '...
# 27   ['breaking', 'an', 'object', 'into', 'smaller'...
# 28                     ['producer', 'and', 'consumer']
# 29                                      ['reflection']
# ..                                                 ...
# 512  ['taking', 'glass', 'bottles', 'to', 'a', 'pla...
# 513                                    ['a', 'pencil']
# 514                                       ['omnivore']
# 515                                  ['electromagnet']
# 516  ['a', 'winter', 'storm', 'that', 'produces', '...
# 517                         ['continental', 'shelves']
# 518                                      ['molecules']
# 519                              ['an', 'observation']
# 520                                        ['insects']
# 521      ['hold', 'a', 'lamp', 'near', 'the', 'floor']
# 522                                 ['rubber', 'band']
# 523                                           ['wind']
# 524  ['the', 'metal', 'rod', 'becomes', 'a', 'liqui...
# 525                              ['picking', 'apples']
# 526                                          ['wings']
# 527                                ['light', 'energy']
# 528  ['the', 'powder', 'dissolves', 'in', 'the', 'w...
# 529                          ['mid', 'ocean', 'ridge']
# 530  ['mercury', 'goes', 'around', 'the', 'sun', 'e...
# 531                                          ['dying']
# 532                                        ['tornado']
# 533                      ['land', 'on', 'the', 'moon']
# 534  ['discuss', 'their', 'observations', 'with', '...
# 535                         ['older', 'than', 'earth']
# 536                                        ['pointed']
# 537                                        ['drought']
# 538                                       ['a', 'dam']
# 539                                         ['region']
# 540                                  ['inner', 'core']
# 541                                 ['pecan', 'trees']
#
#                                                      b  \
# 0    ['the', 'fish', 'was', 'unable', 'to', 'reprod...
# 1        ['bread', 'burns', 'in', 'a', 'toaster', '.']
# 2                           ['looks', 'very', 'shiny']
# 3    ['mars', ',', 'mercury', ',', 'earth', ',', 'v...
# 4    ['its', 'kinetic', 'energy', 'is', 'decreasing...
# 5              ['dip', 'the', 'mineral', 'in', 'acid']
# 6                                            ['earth']
# 7                                            ['black']
# 8    ['it', 'is', 'brighter', 'than', 'other', 'sta...
# 9                                           ['pulley']
# 10                                    ['cell', 'wall']
# 11   ['the', 'fish', 'was', 'carried', 'far', 'inla...
# 12                                        ['engineer']
# 13                                   ['conversations']
# 14   ['pulley', ',', 'inclined', 'plane', ',', 'and...
# 15   ['detailed', 'observations', 'of', 'jupiter', ...
# 16   ['checking', 'the', 'lake', 'water', 'for', 'n...
# 17                                           ['solid']
# 18        ['it', 'was', 'once', 'much', 'warmer', '.']
# 19   ['one', 'flower', 'was', 'measured', 'to', 'be...
# 20   ['the', 'name', 'of', 'the', 'insect', 'and', ...
# 21   ['the', 'sun', 'is', 'the', 'largest', 'and', ...
# 22                                    ['cell', 'wall']
# 23             ['the', 'growth', 'of', 'a', 'crystal']
# 24                                          ['galena']
# 25                                       ['breathing']
# 26   ['mercury', ',', 'earth', ',', 'mars', ',', 'v...
# 27   ['allowing', 'an', 'iron', 'chain', 'to', 'rem...
# 28                    ['consumer', 'and', 'herbivore']
# 29                                      ['refraction']
# ..                                                 ...
# 512  ['using', 'the', 'same', 'foil', 'to', 'cover'...
# 513                                   ['a', 'bicycle']
# 514                                      ['carnivore']
# 515                                      ['insulator']
# 516  ['a', 'rotating', 'funnel', 'shaped', 'cloud',...
# 517                          ['continental', 'slopes']
# 518                                      ['chemicals']
# 519                                ['a', 'conclusion']
# 520                                       ['rainfall']
# 521  ['turn', 'off', 'the', 'lights', 'in', 'the', ...
# 522                                ['cloth', 'ribbon']
# 523                                          ['water']
# 524  ['the', 'metal', 'rod', 'becomes', 'heavier', ...
# 525                             ['feeding', 'animals']
# 526                                           ['eyes']
# 527                                ['solar', 'energy']
# 528          ['the', 'water', 'changes', 'color', '.']
# 529                               ['abyssal', 'plain']
# 530  ['the', 'moon', 'goes', 'around', 'earth', 'ev...
# 531                                       ['inactive']
# 532                                      ['hurricane']
# 533                           ['orbit', 'a', 'planet']
# 534  ['conduct', 'the', 'experiment', 'with', 'more...
# 535                       ['smaller', 'than', 'earth']
# 536                                        ['rounded']
# 537                                   ['thunderstorm']
# 538                                   ['a', 'glacier']
# 539                                          ['niche']
# 540                                          ['crust']
# 541                                  ['pine', 'cones']
#
#                                                      c  \
# 0    ['a', 'mountain', 'used', 'to', 'be', 'in', 't...
# 1      ['a', 'cake', 'bakes', 'in', 'an', 'oven', '.']
# 2                             ['contains', 'crystals']
# 3    ['earth', ',', 'venus', ',', 'mercury', ',', '...
# 4    ['its', 'potential', 'energy', 'is', 'increasi...
# 5    ['heat', 'the', 'mineral', 'until', 'it', 'mel...
# 6                                            ['venus']
# 7                                            ['white']
# 8    ['it', 'is', 'of', 'average', 'brightness', 'c...
# 9                                ['inclined', 'plane']
# 10                                       ['cytoplasm']
# 11   ['the', 'fish', 'and', 'dinosaur', 'were', 'fo...
# 12                                       ['ecologist']
# 13             ['publications', 'and', 'calculations']
# 14   ['wedge', ',', 'wheel', 'and', 'axle', ',', 'a...
# 15   ['the', 'name', 'spectrum', 'for', 'the', 'col...
# 16   ['sampling', 'fish', 'populations', 'in', 'the...
# 17                                          ['liquid']
# 18   ['it', 'has', 'become', 'a', 'rockier', 'place...
# 19   ['on', 'a', 'dark', 'night', ',', 'a', 'studen...
# 20   ['the', 'weight', 'of', 'the', 'insect', 'and'...
# 21   ['most', 'of', 'the', 'stars', 'in', 'the', 'u...
# 22                                     ['chloroplast']
# 23           ['a', 'liquid', 'becoming', 'a', 'solid']
# 24                                         ['bauxite']
# 25                                 ['jumping', 'rope']
# 26   ['mercury', ',', 'venus', ',', 'mars', ',', 'e...
# 27   ['heating', 'a', 'brown', 'substance', 'until'...
# 28                   ['decomposer', 'and', 'producer']
# 29                                     ['diffraction']
# ..                                                 ...
# 512  ['wrapping', 'glasses', 'with', 'newspaper', '...
# 513                             ['a', 'paper', 'clip']
# 514                                      ['herbivore']
# 515                                        ['circuit']
# 516  ['a', 'severe', 'weather', 'condition', 'with'...
# 517                              ['ocean', 'trenches']
# 518                                 ['a', 'vibration']
# 519                                ['a', 'prediction']
# 520                                           ['soil']
# 521  ['sit', 'close', 'to', 'the', 'wall', 'near', ...
# 522                                ['leather', 'shoe']
# 523                                     ['the', 'sun']
# 524  ['the', 'metal', 'rod', 'attracts', 'other', '...
# 525                             ['selling', 'clothes']
# 526                                           ['soil']
# 527                              ['kinetic', 'energy']
# 528   ['the', 'student', 'stirs', 'the', 'water', '.']
# 529                                ['ocean', 'trench']
# 530  ['earth', 'orbits', 'the', 'sun', 'about', 'ev...
# 531                              ['growing', 'taller']
# 532                                       ['blizzard']
# 533                          ['return', 'to', 'earth']
# 534  ['record', 'daily', 'information', 'in', 'a', ...
# 535  ['having', 'the', 'same', 'climate', 'as', 'ea...
# 536                                           ['wide']
# 537                                        ['tornado']
# 538                                     ['a', 'river']
# 539                                         ['family']
# 540                                  ['outer', 'core']
# 541                             ['hardwood', 'lumber']
#
#                                                      d  len_a  len_b  len_c  \
# 0    ['a', 'river', 'used', 'to', 'run', 'through',...      6      6      8
# 1    ['two', 'chemicals', 'form', 'a', 'new', 'subs...      5      6      7
# 2                           ['forms', 'from', 'magma']      3      3      2
# 3    ['venus', ',', 'earth', ',', 'mars', ',', 'mer...      7      7      7
# 4    ['its', 'potential', 'energy', 'is', 'decreasi...      5      6      6
# 5    ['drag', 'an', 'edge', 'of', 'the', 'mineral',...      3      5      6
# 6                                          ['jupiter']      1      1      1
# 7                                           ['yellow']      1      1      1
# 8    ['it', 'is', 'of', 'average', 'brightness', 'c...      7      7      9
# 9                             ['wheel', 'and', 'axle']      1      1      2
# 10                                ['cell', 'membrane']      1      2      1
# 11   ['the', 'dinosaur', 'was', 'swimming', 'from',...     10     11     11
# 12                                    ['veterinarian']      1      1      1
# 13            ['calculations', 'and', 'conversations']      1      1      3
# 14   ['wheel', 'and', 'axle', ',', 'inclined', 'pla...      6      7      8
# 15   ['the', 'term', 'cell', 'to', 'describe', 'the...      7      6      8
# 16   ['observing', 'the', 'surface', 'of', 'the', '...      9     10      9
# 17                                          ['plasma']      1      1      1
# 18   ['it', 'has', 'changed', 'little', 'from', 'th...      5      6      7
# 19   ['people', 'should', 'be', 'careful', 'to', 'p...     10      9     12
# 20   ['the', 'color', 'of', 'the', 'insect', 'and',...     10      9     11
# 21   ['most', 'of', 'the', 'stars', 'in', 'the', 'u...     10     12     13
# 22                                ['cell', 'membrane']      1      2      1
# 23                 ['sedimentation', 'of', 'granules']      4      5      5
# 24                                         ['diamond']      1      1      1
# 25                               ['digesting', 'food']      1      1      2
# 26   ['mercury', ',', 'venus', ',', 'earth', ',', '...     15     15     15
# 27   ['reacting', 'vinegar', 'and', 'baking', 'soda...     10     12     11
# 28                  ['herbivore', 'and', 'decomposer']      3      3      3
# 29                                      ['absorption']      1      1      1
# ..                                                 ...    ...    ...    ...
# 512  ['carrying', 'lunch', 'to', 'school', 'every',...     12      9     11
# 513                       ['a', 'pair', 'of', 'shoes']      2      2      3
# 514                                       ['producer']      1      1      1
# 515                                        ['current']      1      1      1
# 516  ['a', 'storm', 'that', 'forms', 'over', 'warm'...      7     10     10
# 517                              ['abyssal', 'plains']      2      2      2
# 518                         ['a', 'magnetic', 'field']      1      1      2
# 519                                ['an', 'inference']      2      2      2
# 520                                           ['wind']      1      1      1
# 521  ['stand', 'between', 'a', 'light', 'and', 'the...      6      7      8
# 522                                ['wooden', 'board']      2      2      2
# 523                                    ['the', 'moon']      1      1      2
# 524  ['the', 'metal', 'rod', 'produces', 'sound', '.']      7      6      7
# 525                             ['building', 'houses']      2      2      2
# 526                                            ['air']      1      1      1
# 527                            ['renewable', 'energy']      2      2      2
# 528  ['the', 'water', 'is', 'the', 'proper', 'tempe...      7      5      6
# 529                             ['volcanic', 'island']      3      2      2
# 530  ['earth', 'makes', 'one', 'turn', 'on', 'its',...      8      8      8
# 531                       ['growing', 'its', 'leaves']      1      1      2
# 532                               ['freezing', 'rain']      1      1      1
# 533                            ['walk', 'in', 'space']      4      3      3
# 534  ['make', 'up', 'explanations', 'for', 'the', '...     10     11      8
# 535  ['having', 'the', 'same', 'atmosphere', 'as', ...      3      3      6
# 536                                           ['flat']      1      1      1
# 537                                          ['flood']      1      1      1
# 538                            ['a', 'power', 'plant']      2      2      2
# 539                                      ['community']      1      1      1
# 540                                         ['mantle']      2      1      2
# 541                                ['maple', 'leaves']      2      2      2
#
#      len_d
# 0        8
# 1        7
# 2        3
# 3        7
# 4        6
# 5        9
# 6        1
# 7        1
# 8       10
# 9        3
# 10       2
# 11      13
# 12       1
# 13       3
# 14       9
# 15      10
# 16      15
# 17       1
# 18       7
# 19       9
# 20      11
# 21      13
# 22       2
# 23       3
# 24       1
# 25       2
# 26      15
# 27      12
# 28       3
# 29       1
# ..     ...
# 512     11
# 513      4
# 514      1
# 515      1
# 516     13
# 517      2
# 518      3
# 519      2
# 520      1
# 521      7
# 522      2
# 523      2
# 524      6
# 525      2
# 526      1
# 527      2
# 528      7
# 529      2
# 530     10
# 531      3
# 532      2
# 533      3
# 534      7
# 535      6
# 536      1
# 537      1
# 538      3
# 539      1
# 540      1
# 541      2
#
# [542 rows x 20 columns]

# %%
new_data.loc[55]
# Out:
# AnswerKey                                                    B
# question     You are getting up to go to school in Louisian...
# q1           ['you', 'are', 'getting', 'up', 'to', 'go', 't...
# a1              ['earth', 'rotates', 'on', 'its', 'axis', '.']
# wa1          ['earth', 'revolves', 'around', 'the', 'sun', ...
# wa2          ['the', 'sun', 'rotates', 'on', 'its', 'axis',...
# wa3          ['the', 'moon', 'revolves', 'around', 'earth',...
# len_a1                                                       6
# len_wa1                                                      6
# len_wa2                                                      7
# len_wa3                                                      6
# len_q1                                                      31
# a            ['earth', 'revolves', 'around', 'the', 'sun', ...
# b               ['earth', 'rotates', 'on', 'its', 'axis', '.']
# c            ['the', 'sun', 'rotates', 'on', 'its', 'axis',...
# d            ['the', 'moon', 'revolves', 'around', 'earth',...
# len_a                                                        6
# len_b                                                        6
# len_c                                                        7
# len_d                                                        6
# Name: 55, dtype: object
